# %%
import pandas as pd
from pathlib import Path
import datetime as dt

# %%
csvpath = Path("UFOs_coord.csv")

# %%
ufo_data = pd.read_csv(csvpath,encoding="latin-1")
ufo_data.head()
# Out:
#         Date / Time Country        City State    Shape  \
# 0  12/21/2016 19:15     USA  Waynesboro    VA   Sphere
# 1   12/21/2016 0:00     USA  Louisville    KY  Unknown
# 2  12/20/2016 22:30     USA  Santa Rosa    CA   Sphere
# 3  12/20/2016 19:00     USA      Fresno    CA   Circle
# 4  12/19/2016 21:53     USA     Reymert    AZ   Circle
#
#                                              Summary        lat         lng
# 0               Bright round object hovering in sky.  38.065229  -78.905888
# 1  Multiple craft ascending from north of Shelbyv...  38.254238  -85.759407
# 2  Bright orange planet-like object sighted near ...  38.440467 -122.714431
# 3      Twelve orange globes in formation over Fresno  36.729529 -119.708861
# 4  While camping in the Cottonwood canyon Rd., al...  33.229779 -111.209290

# %%
ufo_data[["Date", "Time"]] = ufo_data["Date / Time"].str.split(" ", expand=True)
ufo_data.head(100)
# Out:
#             Date / Time Country            City State     Shape  \
# 0      12/21/2016 19:15     USA      Waynesboro    VA    Sphere
# 1       12/21/2016 0:00     USA      Louisville    KY   Unknown
# 2      12/20/2016 22:30     USA      Santa Rosa    CA    Sphere
# 3      12/20/2016 19:00     USA          Fresno    CA    Circle
# 4      12/19/2016 21:53     USA         Reymert    AZ    Circle
# ..                  ...     ...             ...   ...       ...
# 95  2016-09-12 22.00.00     USA         Phoenix    AZ   Unknown
# 96  2016-09-12 21.50.00     USA        Portland    OR     Flash
# 97  2016-09-12 21.39.00     USA         Oldsmar    FL    Sphere
# 98  2016-09-12 21.30.00     USA         Kingman    AZ  Triangle
# 99  2016-09-12 20.30.00     USA  Fredericksburg    VA    Circle
#
#                                               Summary        lat         lng  \
# 0                Bright round object hovering in sky.  38.065229  -78.905888
# ...

# %%
ufo_data = ufo_data.drop(columns=["Date / Time", "Time"])
ufo_data.head()
# Out:
#   Country        City State    Shape  \
# 0     USA  Waynesboro    VA   Sphere
# 1     USA  Louisville    KY  Unknown
# 2     USA  Santa Rosa    CA   Sphere
# 3     USA      Fresno    CA   Circle
# 4     USA     Reymert    AZ   Circle
#
#                                              Summary        lat         lng  \
# 0               Bright round object hovering in sky.  38.065229  -78.905888
# 1  Multiple craft ascending from north of Shelbyv...  38.254238  -85.759407
# 2  Bright orange planet-like object sighted near ...  38.440467 -122.714431
# 3      Twelve orange globes in formation over Fresno  36.729529 -119.708861
# 4  While camping in the Cottonwood canyon Rd., al...  33.229779 -111.209290
#
#          Date
# 0  12/21/2016
# 1  12/21/2016
# 2  12/20/2016
# 3  12/20/2016
# 4  12/19/2016

# %%
ufo_data["Date"] = pd.to_datetime(ufo_data["Date"])
ufo_data.head(100)
# Out:
#    Country            City State     Shape  \
# 0      USA      Waynesboro    VA    Sphere
# 1      USA      Louisville    KY   Unknown
# 2      USA      Santa Rosa    CA    Sphere
# 3      USA          Fresno    CA    Circle
# 4      USA         Reymert    AZ    Circle
# ..     ...             ...   ...       ...
# 95     USA         Phoenix    AZ   Unknown
# 96     USA        Portland    OR     Flash
# 97     USA         Oldsmar    FL    Sphere
# 98     USA         Kingman    AZ  Triangle
# 99     USA  Fredericksburg    VA    Circle
#
#                                               Summary        lat         lng  \
# 0                Bright round object hovering in sky.  38.065229  -78.905888
# 1   Multiple craft ascending from north of Shelbyv...  38.254238  -85.759407
# 2   Bright orange planet-like object sighted near ...  38.440467 -122.714431
# 3       Twelve orange globes in formation over Fresno  36.729529 -119.708861
# ...

# %%
ufo_data[["Year", "Month/Day"]] = ufo_data["Date"].str.split("-", expand=True)
ufo_data.head(100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ufo_data[["Year", "Month/Day"]] = ufo_data["Date"].str.split("-", expand=True)
#       2 ufo_data.head(100)
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# ...

# %%
ufo_data["Date"] = ufo_data["Date"].dt.strftime("%Y%m%d")
ufo_data.head(100)
